# %%
import urllib.request
import cv2
import numpy as np
import os

# %%
def store_raw_images():
    neg_images_link = 'http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n03379204'
    neg_image_urls = urllib.request.urlopen(neg_images_link).read().decode()
    
    if not os.path.exists('neg'):
        os.makedirs('neg')
        
    pic_num = 1044
    
    for i in neg_image_urls.split('\n'):
        try:
            print(i)
            urllib.request.urlretrieve(i, "neg/"+str(pic_num)+'.jpg')
            img = cv2.imread("neg/"+str(pic_num)+'.jpg', cv2.IMREAD_GRAYSCALE)
            resized_image = cv2.resize(img, (400,400))
            cv2.imwrite("neg/"+str(pic_num)+'.jpg', resized_image)
            pic_num += 1
            
        except Exception as e:
            print(str(e))
            
            
store_raw_images()
# Out:
# http://scarletknights.com/football/stadium/images/louisville-stadium.jpg
# HTTP Error 404: Not Found
# http://img1.pcgames.com.cn/pcgames/0803/13/1035122_zq05_thumb.jpg
# http://www.westside66.org/wcs/lib/wcs/Westside_Stadium_Night.Jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/2396/2120283429_27723c1b24.jpg
# http://i152.photobucket.com/albums/s175/Chimaera1977/ontwerpen/nieuwetribuneavondLOWRES.jpg
# http://www.broncotickets.com/images/football_stadium.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://static.flickr.com/101/315120132_ee3ead974f.jpg
# http://www.riminibeach.it/var/news/storage/images/notizie/maradona-a-cesenatico-calcio-sulla-spiaggia/45635-3-ita-IT/maradona_a_cesenatico_calcio_sulla_spiaggia_medium.jpg
# http://www.betting.ie/news/wp-content/uploads/2008/01/maracana.jpg
# HTTP Error 403: Forbidden
# http://www.secsportsfan.com/images/kyfootballmust.jpg
# http://www2.hum.uu.nl/solis/international/images/brazilie_voetbalstadion.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.wsoccer.com/espanol/ligas_copas/argentina/banfield/estadio/estadio_banfield2.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://www.fussballtempel.net/uefa/ESP/Martinez_Valero2.jpeg
# HTTP Error 404: Not Found
# http://upload.wikimedia.org/wikipedia/commons/thumb/0/00/Football_Stadium.jpg/400px-Football_Stadium.jpg
# http://static.flickr.com/178/424168526_edb53b54ed.jpg
# http://mm.news-record.com/drupal/files/imagecache/zoom_view/files/Images/One_of_two_damaged_goal_posts_at_Elon__039_s_football_stadium.jpeg
# HTTP Error 404: Not Found
# http://www.mercadolibre.com.ar/jm/img?s=MLA&f=39433509_7561.jpg&v=P
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://tour.ua.edu/images/bdstadium.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.secfootball.itgo.com/scott.jpg
# HTTP Error 404: Not Found
# http://www.kielsmanifest.be/Index.stadion.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://lh5.ggpht.com/_7qfnD5_rydo/Rqbpt7-T4YI/AAAAAAAAAhI/rrmBZ5k-pUU/Den+Haag-+Madurodam115+(FootBall+Stadium,+Madurodam).JPG
# http://www.miamisports.org/Football/images/fiu_stadium_2.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://static.flickr.com/164/436522220_c2cc72b5d5.jpg
# http://graphics8.nytimes.com/images/2005/10/21/travel/stadium.184.2.650.jpg
# http://www.meb.marshall.edu/cardiology/images/stadium.jpg
# <urlopen error [Errno 60] Operation timed out>
# http://www.mippin.com/mip/prev/remoteImage.jsp?w=214&url=http%3A%2F%2Fgraphics8.nytimes.com%2Fimages%2F2008%2F12%2F15%2Fsports%2Ffootball%2F15stadium.enlarge.jpg
# HTTP Error 403: Forbidden
# http://imgdujia.kuxun.cn/newpic/518/800518/1.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://www.fathersdaygiftshop.org.uk/images/products/football_stadium_tour_s.gif
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://www.martinferrer.com/Imagenes/valdespartera-int-4-ppt.jpg
# HTTP Error 404: Not Found
# http://www.nationmaster.com/wikimir/images/upload.wikimedia.org/wikipedia/en/thumb/5/57/Windsor_Park_football_stadium_-_Empty.JPG/300px-Windsor_Park_football_stadium_-_Empty.JPG
# HTTP Error 404: NOT FOUND
# http://upload.wikimedia.org/wikipedia/commons/8/85/Estadio_Carlos_Tartiere_05.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/1210/1352892443_6c2feb5ca0.jpg
# http://static.flickr.com/73/193965141_63b7c4b7e1.jpg
# http://www.alhaurintoday.com/newfootballstadium3.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://www.mountida.edu/images/main/Footballteam2.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.take-a-trip.eu/uploads/pics_bezienswaardigheden_nl/Stanford_Bridge_London.jpg
# HTTP Error 404: Not Found
# http://visualrian.com/storage/PreviewWM/3172/66/317266.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://www.yzyz.org/upimg/litimg/photo/b47.jpg
# http://www.gallos-blancos.com/Estadio/Corre5.JPG
# http://www.lagrange.edu/resources/images/athletics/football/Callaway.jpg
# HTTP Error 404: Not Found
# http://images.onesite.com/blogs.telegraph.co.uk/user/bruno_waterfield/footballstadium_.jpg
# HTTP Error 404: Not Found
# http://www.cosasdemadrid.es/images/estadios_de_futbol_en_madrid_.JPG
# HTTP Error 403: Forbidden
# http://graphics.fansonly.com/schools/mem/graphics/liberty-stadium-250-01.jpg
# http://www.missethoreca.nl/upload/6495303_680_1207939540105-man_klein.jpg
# HTTP Error 404: Not Found
# http://www.renesmurf.nl/images/2_copy2.jpg
# http://www.hln.be/static/FOTO/pe/14/2/1/large_496351.jpg
# HTTP Error 404: Not Found
# http://i37.photobucket.com/albums/e58/farokemao/Cartagena_11deNoviembre1-1.jpg
# https://www.depauw.edu/ath/football/1999/images/blackstock.jpg
# http://static.flickr.com/3143/2819472845_7c4c50cf94.jpg
# http://www.webbaviation.co.uk/stadiums/everton-c3482a.jpg
# HTTP Error 403: Forbidden
# http://static.flickr.com/3283/2748140204_3e981587fc.jpg
# http://static.flickr.com/3028/2663231829_30cc953438.jpg
# http://www.carolinaphoto.com/Source/Specials/CBD%20BOA%20Stadium%200905%2026(2).jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.akl.org/images/central_mo_football_stadium.jpg
# HTTP Error 404: Not Found
# http://powerofthought.files.wordpress.com/2007/02/wembley1.jpg
# HTTP Error 404: Not Found
# http://www.cord.edu/dept/sports/images/pics/facility/edited/jake.jpg
# http://www.negotiationlawblog.com/CU%20Football.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://static.flickr.com/75/215760080_87e0e27495.jpg
# http://www.highprofile.nl/images/dynamic/highlight/WillemII_flash.jpg
# HTTP Error 404: Not Found
# http://students.uconn.edu/photos/football_stadium.jpg
# HTTP Error 404: Not Found
# http://upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Camp_nou_2.jpg/250px-Camp_nou_2.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/3058/2748129646_19f2b24e94.jpg
# http://graphics.fansonly.com/schools/clem/graphics/stadium-picture-350.jpg
# http://img89.imageshack.us/img89/9986/0008c16e2e771f708f9080bdv6.jpg
# HTTP Error 404: Not Found
# http://www.irishnews.com/webimages/20080624/news6.jpg
# HTTP Error 404: Not Found
# http://blogimages.seniorennet.be/wareber/565-520be4afac08eae1d9a74f42212e7def.jpg
# http://www.visitlawrence.com/m/files/smFootballStadium.jpg
# HTTP Error 404: Not found
# http://static.flickr.com/1001/1435295035_d9ae0ce14c.jpg
# HTTP Error 404: Not Found
# http://adt_blog.typepad.com/photos/btw_image_gallery/20hoksve_stadium_02.jpg
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'adt_blog.typepad.com'. (_ssl.c:1051)>
# http://www.lsufootballfreak.com/lsu_tiger_stadium_daytime.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://static-p3.fotolia.com/jpg/00/03/37/92/400_F_3379238_JLrEFGnogYi5KLrEOGHwKKMsFlmeXC.jpg
# http://civictrust.net.au/wp-content/uploads/aami_football_stadium.jpg
# HTTP Error 404: Not Found
# http://www.dessosports.com/typo3temp/pics/492936e116.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://football.ballparks.com/NFL/NewOrleansSaints/newinterior.gif
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.theoffside.com/files/2008/11/stadium6.jpg
# <urlopen error [Errno 60] Operation timed out>
# http://lh3.ggpht.com/_2n_d0SFIWrI/RmVx5rIT3kI/AAAAAAAAAHc/rMDIwG65VKI/IMG_8406.jpg
# http://img291.imageshack.us/img291/166/estgm3.jpg
# HTTP Error 404: Not Found
# http://www.egriz.com/GrizPics2/albums/userpics/10001/normal_griz_stadium_from_above.jpg
# HTTP Error 403: Forbidden
# http://static.flickr.com/63/172197467_97d2e7b6d9.jpg
# http://media.thestate.com/smedia/2009/01/07/15/BCS_Championship_Football.sff.standalone.prod_affiliate.74.jpg
