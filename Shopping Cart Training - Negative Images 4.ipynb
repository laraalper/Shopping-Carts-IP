# %%
import urllib.request
import cv2
import numpy as np
import os

# %%
def store_raw_images():
    neg_images_link = 'http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02704949'
    neg_image_urls = urllib.request.urlopen(neg_images_link).read().decode()
    
    if not os.path.exists('neg'):
        os.makedirs('neg')
        
    pic_num = 1727
    
    for i in neg_image_urls.split('\n'):
        try:
            print(i)
            urllib.request.urlretrieve(i, "neg/"+str(pic_num)+'.jpg')
            img = cv2.imread("neg/"+str(pic_num)+'.jpg', cv2.IMREAD_GRAYSCALE)
            resized_image = cv2.resize(img, (400,400))
            cv2.imwrite("neg/"+str(pic_num)+'.jpg', resized_image)
            pic_num += 1
            
        except Exception as e:
            print(str(e))
            
            
store_raw_images()
# Out:
# http://static.flickr.com/3033/3039000670_1b074ec0bd.jpg
# http://static.flickr.com/61/198857284_207fbbea43.jpg
# http://static.flickr.com/108/307574138_e85a09f939.jpg
# http://image52.webshots.com/52/7/12/28/430671228NsDCXQ_fs.jpg
# HTTP Error 404: Not Found
# http://www.craigporter.com/images/holidays/italia2003/roma/colosseum01.jpg
# http://static.flickr.com/2390/2153667084_514577a3c8.jpg
# http://static.flickr.com/3259/2597787990_259a9bcdeb.jpg
# http://static.flickr.com/1181/916053283_e66800de38.jpg
# HTTP Error 410: Gone
# http://static.flickr.com/51/169954838_032b6e94bf.jpg
# http://static.px.yelp.com/bphoto/eDuRL7eFf5hLYdr-TNGbGA/l
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'static.px.yelp.com'. (_ssl.c:1051)>
# http://www.planetware.com/i/photo/colosseum-rome-rcol4.jpg
# http://nowai.files.wordpress.com/2006/07/coliseum_1360.jpg
# http://www.laregioninternacional.com/resize.php?pic=imagenes/galeria/coliseo.jpg
# HTTP Error 403: Forbidden
# http://static.flickr.com/1378/685416572_8ffe86419a.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/122/275527394_08c01464c9.jpg
# http://www.kunstreis.com/images/rome/IMG_1850.jpg
# http://www.kamen-pazin.hr/slike/arena_mala.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/61/178303582_b1de9373ee.jpg
# http://img.timeinc.net/time/photoessays/2007/wonders_a/colosseum.jpg
# http://www.jmu.edu/international/images/Coliseum_000.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://hette.web-log.nl/photos/uncategorized/2008/03/09/colosseum1.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://static.flickr.com/2043/2077920170_b9acaaca7c.jpg
# http://www.photosbycrosby.com/Photos-Shelly/ColosseumRome_resized.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://bp2.blogger.com/_fer2bVkKi84/Rq4SMGfKzTI/AAAAAAAAAZ8/2hxtuW8kXdo/s320/coliseo.jpg
# http://www.city-data.com/forum/members/crisp444-205114-albums-best-italy-pic1733-coliseum-rome.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://bp3.blogger.com/_5T4sK7FhJwY/SJTNPZEoR9I/AAAAAAAAAXQ/OT4iOiY0Z9I/s400/Rome-Coliseum5.JPG
# http://static.flickr.com/248/445508176_3557e97648.jpg
# http://www.zeetours.nl/images/beheer/Rome%20Colosseum.jpg
# HTTP Error 404: Not Found
# http://www.heriquest.com/img/gallery/gallery_629.jpg
# http://www.digital-images.net/Images/Rome/Rome_Select/Colosseum_6714.jpg
# http://static.flickr.com/3110/3116853804_724a3ab489.jpg
# http://img6.travelblog.org/Photos/1317/282191/t/2406314-The-Amphitheatre-in-Nimes-0.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://photos.jpgmag.com/1186306_154850_447fd22821_m.jpg
# HTTP Error 404: Not Found
# http://library.thinkquest.org/CR0215635/shirley/amp%20pic.bmp
# <urlopen error [Errno 60] Operation timed out>
# http://clio.rediris.es/fichas/Gladiator/GLADIATORL_archivos/FOTOCOLISEOANTES.jpg
# http://static.flickr.com/183/428282479_9c540ad917.jpg
# http://static.flickr.com/112/305017146_5828b7116c.jpg
# http://www.sempai.org/~felicia/wedding/pics/honey/0023-Colosseum.jpg
# HTTP Error 404: Not Found
# http://slike.gradpula.com/slikeid/arena22.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://i6.photobucket.com/albums/y212/paverpol/Argusvlinder2007/Juli2007/JaneMarthaSt.JohnTheColosseum1856.jpg
# http://www.nycerome.com/fotos-de-roma/coliseo-roma.jpg
# HTTP Error 408: Request Time-out
# http://www.rockandrollroadmap.com/gfx/mcafee.jpg
# HTTP Error 404: Not Found
# http://www.nycerome.com/img-roma-hoteles/areas-de-roma-pic/zona-coliseo/roma-colosseo.jpg
# HTTP Error 408: Request Time-out
# http://cache.virtualtourist.com/1/816443-Ruins_and_history-Pompeii.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://static.flickr.com/3148/2597805188_b4a862bd60.jpg
# http://static.flickr.com/3116/2839871698_cf819fd34c.jpg
# HTTP Error 404: Not Found
# http://j.b5z.net/i/u/2044088/i/Coliseum_day.jpg
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1051)>
# http://static.flickr.com/3286/2433979771_47d1f0aa2a.jpg
# http://carandpuj.com/images/08-roma%20paris%2012-2005/08-031-colosseum.jpg
# http://imagecache2.allposters.com/images/pic/PTGPOD/531993~The-Colosseum-Rome-Italy-Posters.jpg
# http://upload.wikimedia.org/wikipedia/commons/thumb/5/53/Colosseum_in_Rome,_Italy_-_April_2007.jpg/800px-Colosseum_in_Rome,_Italy_-_April_2007.jpg
# http://xamg.xamg.googlepages.com/coliseo_2.jpg/coliseo_2-full.jpg
# HTTP Error 404: Not Found
# http://static.flickr.com/3074/2712674351_b24936e8ff.jpg
# http://www.panoramio.com/photos/original/4191819.jpg
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.panoramio.com'. (_ssl.c:1051)>
# http://stevenanddeborah.com/images/rome_coliseum.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://www.jimmyregister.com/Pictures/Coliseum.jpg
# http://www.siu.edu/~dfll/bigham/Rome/RomanPics/Colosseum1.jpg
# HTTP Error 404: Not Found
# http://imagecache2.allposters.com/images/pic/BRGPOD/238528~Aerial-View-of-the-Colosseum-in-Rome-from-Views-of-Rome-Posters.jpg
# http://members.shaw.ca/pelligroso/Images/Coliseum.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.chacocanyon.com/images/coliseum.jpeg
# HTTP Error 404: Not Found
# http://static.flickr.com/3071/2635109689_0e20fbc2dd.jpg
# http://static.flickr.com/33/41356908_0c4fc0ce88.jpg
# http://www.qcsd.org/21304162793515/lib/21304162793515/Roman-coliseum.jpg
# HTTP Error 404: Not Found
# http://www.romaspqr.it/ROMA/Colosseo2.jpeg
# http://static.flickr.com/1308/1250653823_ec56880790.jpg
# HTTP Error 404: Not Found
# http://z.about.com/d/architecture/1/0/E/l/Colloseumaerial.jpg
# HTTP Error 404: Not Found
# http://i23.photobucket.com/albums/b385/chanelismypoison/colosseum.jpg
# http://bp1.blogger.com/_78aAI76v0cc/RpGaiTnNy4I/AAAAAAAAAoY/hLZM_kCi9PM/s400/El+coliseo+de+Roma.jpg
# http://naturephotographer.net/npimages/rome_coliseum/thumbnails/rco1b.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://www.surfthedream.com.au/__data/assets/image/0017/1448/colosseum_rome.jpg
# HTTP Error 403: Forbidden
# http://home.pacbell.net/sergey-k/images/Coliseum01.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://static.flickr.com/2334/2270901094_7d2142d20d.jpg
# HTTP Error 404: Not Found
# http://www.primeroscristianos.com/images/tesoros_roma/coliseo/coliseo_4.JPG
# HTTP Error 404: Not Found
# http://photos.igougo.com/images/p223742-Rome-Colosseum_Floor.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://static.flickr.com/138/334958631_39482dce1a.jpg
# http://www.reigate.ac.uk/subwebs/subweb_cc_arch/pompeii06/theatre.jpg
# HTTP Error 404: Not Found
# http://www.austriahungaryphotos.com/images/071125223809_Pula_Arena_Coliseum_LG.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://www.photochart.com/data/media/6/Rome__colosseum.jpg
# HTTP Error 403: Forbidden
# http://education.washington.edu/areas/ci/students/images/Rome_sm.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.ojodigital.com/foro/attachments/urbanas-pueblos-y-ciudades/5597d1180940355-imaginaros-50-000-romanos-enfurecidos-ahi-dentro-coliseo.jpg
# http://static.flickr.com/3206/2950727752_160dcecf3b.jpg
# HTTP Error 404: Not Found
# http://home.wish.net/~mgelten/Staatshoofden/Romeinen/Colosseum.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://aureliada.files.wordpress.com/2007/07/roma_coliseo_g.jpg
# http://campustour.wvu.edu/images/video/Coliseum.gif?1218225831
# <urlopen error [Errno 60] Operation timed out>
# http://www.jalle.nu/Mbild06/Bilder/Arena-di-verona.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://www.brics.dk/~brabrand/Italy/Roma2002/colosseum.jpg
# HTTP Error 404: Not Found
# http://www.dreamstime.com/thumb_4/1098706380U0qibf.jpg
# HTTP Error 404: Not Found
# http://www.seatdata.com/images/venue_mcafee_coliseum/samples/sample.jpg
# HTTP Error 404: Not Found
# http://www.stormeducational.co.uk/romans/everyday_life/Images/coliseum.jpg
# HTTP Error 404: Not Found
# http://www.bigfoto.com/europe/italy/rome/colosseum-rome-italy.jpg
# HTTP Error 403: Forbidden
# http://farm3.static.flickr.com/2345/2250237927_73cd547ce6.jpg?v=0
# http://www.wcg.org/wn/98/98JULY/18-Coliseum.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://farm4.static.flickr.com/3271/2951499128_e434f8f983.jpg?v=0
# http://www.mevaco.co.uk/uploads/media/10_LB_qg_Salzburgarena_v4_2004_vq.jpg
# HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# http://annameadows.com/wp-content/uploads/2007/12/colosseum.JPG
# HTTP Error 403: Forbidden
# http://i6.photobucket.com/albums/y207/chiro333/DSC_5082-ColiseoOK.jpg
# HTTP Error 503: Service Unavailable
# http://www.yorku.ca/web/futurestudents/yea/images/coliseum.gif
# HTTP Error 404: Not Found
# http://www.terragalleria.com/images/wallpaper-samples/11.jpeg
# http://personal.telefonica.terra.es/web/iolus/fotos/roma2/mini_interior_coliseo.jpg
# <urlopen error [Errno 60] Operation timed out>
# http://static.flickr.com/47/152571813_e030ed20b2.jpg
# HTTP Error 410: Gone
# http://static.flickr.com/3271/2845753460_ea295772a8.jpg
# http://www.pedaleandoelglobo.com/diario/imagenes/04-ElColiseo.jpg
# HTTP Error 404: Not Found
jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.tropea.biz/images/porto-tropea/anfiteatro-porto-tropea.jpg
# HTTP Error 403: Forbidden
# http://www.shunya.net/Pictures/Italia/colosseum2.jpg
# http://www.the7adventures.com/pics/project_petra/colosseum_gr.jpg
# HTTP Error 404: Not Found
# http://www.italy-travel.net/coliseum.jpg
# http://www.fresno.k12.ca.us/divdept/sscience/images/Coliseum.gif
# HTTP Error 404: Not Found
# http://www.wereldorientatie.net/htm/lesprogramma/Platenalbums/Alex/images/040%20Alex%20buiten%20bij%20het%20Colosseum_jpg.jpg
# HTTP Error 403: Forbidden
# http://www.ihistory101.net/espanol/italy-pic/rf-rome-colosseum-large-floor.jpg
# HTTP Error 403: Forbidden
# http://static.flickr.com/3197/2357826633_93c3b736da.jpg
# http://www.dakubu.net/images/Sarahs_Wedding/Mahrya_and_Jorge/colosseum.JPG
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://imagecache2.allposters.com/images/pic/JUPPOD/030503_1915_0002_xshsa~Ruins-of-the-Coliseum-in-Rome-Against-Blue-Sky-Posters.jpg
# http://static.flickr.com/93/234907930_ca6c94a70d.jpg
# http://www.focusglobe.com/Rome/images/Colosseum.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.florenceart.it/booking/colosseum/colosseum1.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://static.flickr.com/3246/3012364394_b15aae1f5c.jpg
# http://www.177dvd.cn/photo/fashion/5.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://static.flickr.com/225/468870820_439a6c55d2.jpg
# http://static.flickr.com/3020/3022931802_f86720bcc1.jpg
# http://www.planetware.com/i/photo/colosseum-rome-ir1035.jpg
# http://goldmedalticket.com/images/coliseum.gif
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://americandiscountcruises.com/images/europe_coliseum.jpg
# http://static.flickr.com/2303/2420980601_6aa3e95f85.jpg
# HTTP Error 404: Not Found
# http://www.tc.umn.edu/~yang0289/Rome_Coliseum03.jpg
# HTTP Error 404: Not Found
# http://upload.wikimedia.org/wikipedia/commons/b/be/Colosseum.jpg
# http://www.bible-history.com/archaeology/rome/1-colosseum-bb.jpg
# http://www.chicagobusiness.com/images/random/ogColiseum1.gif
# HTTP Error 403: Forbidden
# http://www.romeguide.it/MONUM/ARCHEOL/colosseum/come%20era.jpg
# http://static.flickr.com/3112/2911910827_4ef5f9d587.jpg
# http://imagene.youropi.com/colosseum-rome1(p:activity,482)(c:0).jpg
# HTTP Error 404: Not Found
# http://www.ettyhillesumlyceum.nl/Locaties/VL/vakken/KCV/Trier/pompamf.JPG
# HTTP Error 404: Not Found
# http://www.elpaso.net/~mdudley/europe/coliseum.jpg
# HTTP Error 404: Not Found
# http://www.mercury2006.org/Portals/31/Repository/15/coliseum_nimes.81e9e8cf-5f95-40df-93aa-0e68a5d499ad.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://z.about.com/d/archaeology/1/0/a/A/coliseum.jpg
# HTTP Error 404: Not Found
# http://albegor.com/Photos/Vespatour06Colosseum.jpg
# http://static.flickr.com/1409/822628404_15f40200c2.jpg
# HTTP Error 404: Not Found
# http://imagecache2.allposters.com/images/pic/FIP/IT-00046-C~Colosseum-Rome-Italy-Posters.jpg
# http://static.flickr.com/227/468871010_51ed83937e.jpg
# http://faculty.berea.edu/pearcej/Zolondek/Coliseum3.GIF
# HTTP Error 403: Forbidden
# http://www.akgates.co.uk/holidays/rome/photos/Colosseum1.JPG
# HTTP Error 404: Not Found
# http://www.globusjourneys.com/Common/Images/Destinations/the_colosseum.jpg
# http://photos.igougo.com/images/p392772-Rome-The_Colosseum.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.egrupos.net/albumPhoto/1725669/photo_6.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.auuuu.com/images/turism/Coliseum_Rome_Italy.jpg
# http://www.geocities.com/ieee754/arith16/roman-colosseum.JPG
# [Errno 54] Connection reset by peer
# http://imagecache2.allposters.com/images/pic/FIP/AH-00005-C~Colosseum-Posters.jpg
# http://home.tiscali.nl/vanderklugtreizen/vanderklugtreizen/images/colosseum.jpg
# <urlopen error [Errno 60] Operation timed out>
# http://www.qsov.com/Italy2001/1Colosseum1.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://gdgpi.gdcic.net/photo/PicLib/MidPic/2004p/PhotoC/20040819/20040819000a_2.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://pleasingvacations.com/Images/Colosseum_Italy_Vacations.JPG
# http://static.flickr.com/2168/2263989393_1bc9900a4b.jpg
# http://photos.igougo.com/images/p109773-Rome-Exterior_of_Colosseum.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://cache.virtualtourist.com/3678380-The_Roman_Colosseum-Rome.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.sxc.hu/pic/m/h/ho/hopee/354225_coliseum.jpg
# <urlopen error [Errno 60] Operation timed out>
# http://www.horizonsunlimited.com/tstories/coan/images/ColiseumElJem.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://static.flickr.com/3112/2286313087_e34fabcced.jpg
# http://www.rome-hotels.redflag.info/pictures/colosseum3.jpg
# http://imagecache2.allposters.com/images/pic/PTGPOD/432515-FB~Colosseum-Rome-Italy-Posters.jpg
# http://enpo.org/wp-content/uploads/2008/10/colosseum-from-the-top.jpg
# HTTP Error 403: Forbidden
# http://www.seapahn.us/panoramic/pano_col_med.jpg
# http://recherche.ircam.fr/equipes/analyse-synthese/peeters/WHOAMI/IMAGES/Rome-Coliseum-trans.gif
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://www.ehow.com/images/GlobalPhoto/Articles/2055436/rome-coliseum_Full.jpg
# HTTP Error 410: Gone
# http://webzoom.freewebs.com/zivtamari/coliseum.jpg
# [Errno 54] Connection reset by peer
# http://test.globusjourneys.com/Common/Images/Destinations/colosseum.jpg
# http://upload.wikimedia.org/wikipedia/commons/archive/b/be/20050610143858!Colosseum.jpg
# http://static.flickr.com/3104/2627152668_24334c068c.jpg
# http://static.flickr.com/2041/2507472747_88cf78c2ee.jpg
# https://www.continentalbook.com/pics/coliseum.jpg
# HTTP Error 404: Not Found
# http://photos.igougo.com/images/p64724-Rome-The_Colosseum.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://static.flickr.com/2373/1579833526_fb6acf9bb8.jpg
# http://static.flickr.com/30/64384298_e208744094.jpg
# http://fhtms.sbschools.net/users/bwight/2002/mollyf/colosseum.gif
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://naceland.com/Europe/pictures/Rome/July%209/the%20colosseum.JPG
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://static.flickr.com/2225/2067084414_74265c6b5b.jpg
# HTTP Error 404: Not Found
# http://www.toplumdusmani.net/resim/yedi/roma-coliseum.jpg
# http://static.flickr.com/1322/1029685598_38318ef173.jpg
# http://static.flickr.com/58/174287738_f645ff822e.jpg
# http://fanfarefem.web-log.nl/photos/uncategorized/colosseum.jpg
# OpenCV(4.1.0) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# http://yelnick.typepad.com/photos/uncategorized/coliseumtitle.jpg
# http://www.colosseum.co.uk/wp-content/uploads/2008/06/colosseum-by-night.jpg
# HTTP Error 404: Not Found
# http://www.sambarrowart.com/PhotographyPICS/Coliseum.JPG
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# http://coritel.it:8080/ngi2005/images/rome1.jpg
# <urlopen error [Errno 60] Operation timed out>
# http://www.holiday-beds-direct.com/images/destinations/rome-07.jpg
# ---------------------------------------------------------------------
# gaierror                            Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# /anaconda3/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                   Traceback (most recent call last)
# <ipython-input-4-e56aed0a2f47> in <module>
#      21
#      22
# ---> 23 store_raw_images()
#
# <ipython-input-4-e56aed0a2f47> in store_raw_images()
#      11         try:
#      12             print(i)
# ---> 13             urllib.request.urlretrieve(i, "neg/"+str(pic_num)+'.jpg')
#      14             img = cv2.imread("neg/"+str(pic_num)+'.jpg', cv2.IMREAD_GRAYSCALE)
#      15             resized_image = cv2.resize(img, (400,400))
#
# /anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# /anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /anaconda3/lib/python3.7/urllib/request.py in http_open(self, req)
#    1343
#    1344     def http_open(self, req):
# -> 1345         return self.do_open(http.client.HTTPConnection, req)
#    1346
#    1347     http_request = AbstractHTTPHandler.do_request_
#
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# KeyboardInterrupt:
